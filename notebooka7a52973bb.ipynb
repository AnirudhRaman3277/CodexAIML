# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Step 1
df = pd.read_csv("/kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv")

# %%
# Step 2
plt.scatter(df['YearsExperience'], df['Salary'])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter Plot")
plt.show()

# %%
# Step 3
X = df[['YearsExperience']]
Y = df['Salary']

# %%
# Step 4
model = LinearRegression()
model.fit(X,Y) # calculates best fitting relation betweeen x and y
slope = model.coef_[0] # represents coeff of x in y = mx + b
intercept = model.intercept_ # point where regression line crosses

# %%
# Step 5
def linear_regression(x):
    return slope * x + intercept

# %%
# Step 6
plt.scatter(df['YearsExperience'], df['Salary'], label = 'data Points')
plt.plot(df['YearsExperience'], [linear_regression(xi) for xi in df['YearsExperience']], color = 'red', label = 'Regression Line')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.title("Linear Regression")
plt.show()

# %%
new_x = 6
prediction = linear_regression(new_x)
print(f"Prediction for x = {new_x}: {prediction}")

new_x = pd.DataFrame({'YearsExperience' : [6] })
print(model.predict(new_x))
# Out:
# Prediction for x = 6: 81547.97789525366
# [81547.97789525]

# %%
new_x = 6
prediction = linear_regression(new_x)
print(f"Prediction for x = {new_x}: {prediction}")

new_x = pd.DataFrame({'YearsExperience' : [1] })
print(model.predict(new_x))
# Out:
# Prediction for x = 6: 81547.97789525366
# [34298.16628798]

# %%
new_x = 6
prediction = linear_regression(new_x)
print(f"Prediction for x = {new_x}: {prediction}")

new_x = pd.DataFrame({'YearsExperience' : [0] })
print(model.predict(new_x))
# Out:
# Prediction for x = 6: 81547.97789525366
# [24848.20396652]
